# %% [markdown]
# # XGBoost Trading Strategy
#
# <div class="alert alert-block alert-info">
#
# * Section 2: The strategy can be run fully, meaning that XGBoost will be used to forecast, and these forecasts will be used for backtesting
# * Section 3: The strategy can be run using the pre-computed predictions, which will be used for backtesting (Faster)
#
# <b>Note:</b> The data used in this notebook is sourced from FirstRate Data. To run this notebook, the FirstRate Data, or equivalent data in the same format, is required. </div>

# %% [markdown]
# ### 1. Imports

# %%
import numpy as np
from numpy import asarray
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor
from matplotlib import pyplot as plt
import csv
import pandas as pd

import os, sys

sys.path.append(os.path.abspath('../pysystemtrade'))

from sysdata.sim.csv_futures_sim_data import csvFuturesSimData
from sysquant.estimators.vol import robust_vol_calc
from systems.accounts.account_forecast import pandl_for_instrument_forecast

# %% [markdown]
# ### 2. Read in and Pre-process Data

# %%
CRUDE_OIL = 'CL'
NAT_GAS = 'NG'
BRENT_CRUDE = 'BZ'
GAS = 'RB'
HEAT_OIL = 'HO'

fuel_futures = [CRUDE_OIL, NAT_GAS, BRENT_CRUDE, GAS, HEAT_OIL]

S_P_500 = 'ES'
NASDAQ = 'NQ'
EUROSTOXX = 'FX'
DAX = 'DY'
FT_100 = 'X'

equity_futures = [S_P_500, NASDAQ, EUROSTOXX, DAX, FT_100]

# %%
# Define the data paths according to the structure of the project
FUEL_FUTURES_PATH = '../data/fuel_first_rate_data_R_prices.parquet'
EQUITY_FUTURES_PATH = '../data/equity_indices_first_rate_data_R_prices.parquet'

CSV_PATH = '../pysystemtrade/data/firstrate_futures/xgboost'

# %%
# Read in data
start_datetime = '2018-01-02'

fuel_futures_data = pd.read_parquet(FUEL_FUTURES_PATH)
equity_futures_data = pd.read_parquet(EQUITY_FUTURES_PATH)

# %%
# Function to convert data in a futures data file into individual csv files
def convert_parquet_to_csv(src_dataframe: pd.DataFrame, dst_path: str, symbols: list) -> None:
    """Converts a dataframe containing data from a parquet into individual csv files, according to the data format of the FirstRate futures data bundles.

    Args:
        src_dataframe (pd.DataFrame): source of the futures data
        dst_path (str): destination path where csv files will be saved
        symbols (list): list of futures symbols (str) to create csv files of (all symbols must appear in src_dataframe's columns)
    """

    for i, column in enumerate(symbols):

        dst_filename = dst_path + f'/{symbols[i]}_daily.csv'

        # Resample the dataframe to have daily prices as we will predict the daily average
        curr_futures_data_daily_avg = src_dataframe[symbols[i]].resample("D").mean().dropna()
    
        curr_futures_data_daily_avg.to_csv(dst_filename, header=["price"])

        # Replaces 'Datetime' with 'DATETIME' in csv file to match with pysystemtrade's data
        in_csv_file = open(dst_filename, "r")
        csv_reader = csv.reader(in_csv_file)

        lines = list(csv_reader)
        lines[0][0] = 'DATETIME'  # The cell at (0,0) will always be 'Datetime'

        # Separate file object exclusively for writing
        out_csv_file = open(dst_filename, "w")
        csv_writer = csv.writer(out_csv_file)
        csv_writer.writerows(lines)

        in_csv_file.close()
        out_csv_file.close()

# %%
convert_parquet_to_csv(fuel_futures_data, CSV_PATH, fuel_futures)
convert_parquet_to_csv(equity_futures_data, CSV_PATH, equity_futures)

# %%
def transform_series(data: pd.DataFrame, input_seq_len: int, output_len: int = 1):
    """Transforms the given data into a supervised learning dataset.

    Args:
        data (pd.DataFrame): The input data to be transformed
        input_seq_len (int): The length of the input sequences in the transformed dataset
        output_len (int, optional): The length of the output values in the transformed dataset. Defaults to 1.

    Returns:
        The transformed dataset represented for Numpy
    """
    columns = []

    for i in range(input_seq_len, 0, -1):
        columns.append(data.shift(i))

    for j in range(0, output_len):
        columns.append(data.shift(-j))

    transformed_data = pd.concat(columns, axis = 1)
    transformed_data = transformed_data.dropna()
    return transformed_data.values

# %%
def split_training_testing(data, test_len: int):
	"""A simple splitting function to split the given data into a testing and training set

	Args:
		data: Data to be split
		test_len: Length of the test dataset

	Returns:
		(training set, test set)
	"""
	return data[:test_len, :], data[test_len:, :]


def forecast_XGBoost(train_set, test_set_X):
	"""Forecast using XGBoost's Regressor, using 250 estimators

	Args:
		train_set: training set for XGBoost Regressor
		test_set_X: input values of test set to make predictions

	Returns:
		_type_: _description_
	"""
	train = asarray(train_set)

	trainX, trainy = train[:, :-1], train[:, -1]

	xgboost_model = XGBRegressor(objective='reg:squarederror', n_estimators=250)
	xgboost_model.fit(trainX, trainy)

	test_set_predictions = xgboost_model.predict(asarray([test_set_X]))
	return test_set_predictions

def walk_forward_validation(data, test_len):
	"""Carry out walk forward validation for XGBoost forecasting

	Args:
		data : validation data
		test_len : length of the test set

	Returns:
		Mean absolute error of XGBoost forecasts, the test set's output values, XGBoost's forecasts
	"""
	xgb_predictions = []
	train, test = split_training_testing(data, test_len)

	history = [x for x in train]

	for i in range(len(test)):
		test_X, test_y = test[i, :-1], test[i, -1]

		prediction = forecast_XGBoost(history, test_X)

		xgb_predictions.append(prediction)
		history.append(test[i])
		print(f'Expected: {test_y}, Forecasted: {prediction}')
	# estimate prediction error
	error = mean_absolute_error(test[:, -1], xgb_predictions)
	return error, test[:, -1], xgb_predictions

# %% [markdown]
# ### 2. XGBoost Forecasting and Backtesting

# %% [markdown]
# #### 2.1  XGBoost on Fuel Futures
# - This implementation carries out the full forecasting by the XGBoost regressor, and saves the predictions.

# %%
# Initialize array to store all backtest results
accounts = []
fuel_futures_data = pd.read_parquet('../data/fuel_first_rate_data_R_prices.parquet')
time_steps = 6
for i in range(len(fuel_futures)):
    print(f"COLUMN: {fuel_futures[i]} ------------------------- ")
    curr_futures_data = fuel_futures_data[fuel_futures[i]]
    
    # Convert the futures hourly data into daily data
    curr_futures_data_daily_avg = curr_futures_data.resample("D").mean().dropna()

    
    # Transform data
    data = transform_series(curr_futures_data, input_seq_len=6)
    
    test_startdate = pd.Timestamp('2018-01-01')
    test_len = len(curr_futures_data_daily_avg[test_startdate:])
    
    
    mae, y, predictions = walk_forward_validation(data, test_len)
    print('MAE: %.3f' % mae)

    predictions = pd.Series(predictions, index=curr_futures_data_daily_avg.index[-test_len:])
    
    predictions.to_csv(f'../ARIMA-XGBoost-saved-data/{fuel_futures[i]}_daily_predictions.csv')
    
    short_test_y = pd.Series(y, index=curr_futures_data_daily_avg.index[-test_len:])

    plt.figure(figsize=(20,5))
    plt.plot(predictions, label='Predicted')
    plt.plot(short_test_y, label='True')
    plt.legend()
    plt.savefig(f'../ARIMA-XGBoost-figs/{fuel_futures[i]}_daily_pred_true')
    plt.show()

    forecasts = predictions.diff()

    test_enddate = pd.Timestamp(curr_futures_data_daily_avg.index[-1])

    idx = pd.date_range(test_startdate, test_enddate, freq='D')

    curr_forecast = pd.Series(forecasts)
    curr_forecast.columns = ['forecast']
    curr_forecast.reindex(idx, fill_value=0.0)

    # Convert csv data into data object for pysystemtrade
    instrument_data = csvFuturesSimData(csv_data_paths=dict(csvFuturesAdjustedPricesData="data.firstrate_futures.xgboost"))

        # Get daily prices and calculate the ewmac forecast
    price = instrument_data.get_raw_price(f'{fuel_futures[i]}_daily')
    price_oos = price[test_startdate:test_enddate]
    curr_forecast.reindex(price_oos.index, fill_value=0.0)

    account = pandl_for_instrument_forecast(forecast=curr_forecast, price=price_oos)
    accounts.append(account)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> The output predictions of the above cell can be found in the ../ARIMA-XGBoost-saved-data directory. </div>

# %% [markdown]
# #### 2.1  XGBoost on Equity Futures
# - This implementation carries out the full forecasting by the XGBoost regressor, and saves the predictions.

# %%
equity_accounts = []
equity_futures_data = pd.read_parquet('../data/equity_indices_first_rate_data_R_prices.parquet')
for i in range(len(equity_futures)):
    print(f"COLUMN: {equity_futures[i]} ------------------------- ")
    curr_futures_data = equity_futures_data[equity_futures[i]]
    
    curr_futures_data_daily_avg = curr_futures_data.resample("D").mean().dropna()

    
    # transform the time series data into supervised learning
    data = transform_series(curr_futures_data, input_seq_len=6)
    
    test_startdate = pd.Timestamp('2018-01-01')
    test_len = len(curr_futures_data_daily_avg[test_startdate:])
    
    mean_abs_error, y, xgb_predictions = walk_forward_validation(data, test_len)
    print('MAE: %.3f' % mae)

    # Store the XGBoost predictions
    xgb_predictions = pd.Series(xgb_predictions, index=curr_futures_data_daily_avg.index[-test_len:])
    
    xgb_predictions.to_csv(f'../ARIMA-XGBoost-saved-data/{equity_futures[i]}_daily_predictions.csv')
    
    # Plot predicted vs. true
    short_test_y = pd.Series(y, index=curr_futures_data_daily_avg.index[-test_len:])

    plt.figure(figsize=(20,5))
    plt.plot(xgb_predictions, label='Predicted')
    plt.plot(short_test_y, label='True')
    plt.legend()
    plt.savefig(f'../ARIMA-XGBoost-figs/{equity_futures[i]}_daily_pred_true')
    plt.show()

    # Get the forecasts of the price movement
    forecasts = xgb_predictions.diff()

    # Backtest
    test_enddate = pd.Timestamp(curr_futures_data_daily_avg.index[-1])

    idx = pd.date_range(test_startdate, test_enddate, freq='D')

    curr_forecast = pd.Series(forecasts)
    curr_forecast.columns = ['forecast']
    curr_forecast.reindex(idx, fill_value=0.0)

    # Convert csv data into data object for pysystemtrade
    instrument_data = csvFuturesSimData(csv_data_paths=dict(csvFuturesAdjustedPricesData="data.firstrate_futures.xgboost"))

    price = instrument_data.get_raw_price(f'{fuel_futures[i]}_daily')
    price_oos = price[test_startdate:test_enddate]
    curr_forecast.reindex(price_oos.index, fill_value=0.0)

    account = pandl_for_instrument_forecast(forecast=curr_forecast, price=price_oos)
    accounts.append(account)
# Out:
# COLUMN: ES -------------------------
# Datetime
# 2007-08-20    1236.640625
# 2007-08-21    1240.166667
# Name: ES, dtype: float64
# >expected=2642.4, predicted=2649.9
# >expected=2651.0, predicted=2649.3
# >expected=2667.5, predicted=2649.5
# >expected=2684.1, predicted=2650.2
# >expected=2695.1, predicted=2677.3
# >expected=2708.5, predicted=2682.6
# >expected=2706.8, predicted=2691.6
# >expected=2713.7, predicted=2706.5
# >expected=2710.4, predicted=2709.8
# >expected=2723.7, predicted=2711.1
# >expected=2741.2, predicted=2721.4
# >expected=2757.6, predicted=2739.0
# >expected=2757.2, predicted=2756.8
# >expected=2754.4, predicted=2756.8
# >expected=2759.0, predicted=2756.8
# >expected=2763.5, predicted=2755.4
# >expected=2766.1, predicted=2760.1
# >expected=2770.9, predicted=2765.1
# >expected=2784.5, predicted=2770.0
# >expected=2801.7, predicted=2783.3
# >expected=2804.8, predicted=2793.8
# >expected=2806.0, predicted=2803.7
# >expected=2817.1, predicted=2805.1
# >expected=2839.2, predicted=2816.4
# >expected=2824.2, predicted=2838.0
# >expected=2795.5, predicted=2824.1
# >expected=2794.4, predicted=2795.5
# >expected=2789.2, predicted=2794.4
# >expected=2758.7, predicted=2789.5
# >expected=2708.0, predicted=2759.3
# >expected=2652.6, predicted=2730.2
# >expected=2607.7, predicted=2622.3
# >expected=2641.5, predicted=2599.2
# >expected=2600.2, predicted=2642.3
# >expected=2560.5, predicted=2648.0
# >expected=2597.4, predicted=2579.4
# >expected=2611.8, predicted=2580.3
# >expected=2615.5, predicted=2626.7
# >expected=2645.1, predicted=2616.8
# >expected=2682.7, predicted=2658.7
# >expected=2701.4, predicted=2679.4
# >expected=2706.9, predicted=2701.9
# >expected=2696.8, predicted=2708.7
# >expected=2684.3, predicted=2703.5
# >expected=2673.4, predicted=2684.0
# >expected=2671.3, predicted=2673.8
# >expected=2688.1, predicted=2676.9
# >expected=2711.5, predicted=2694.0
# >expected=2731.2, predicted=2731.1
# >expected=2727.9, predicted=2744.8
# >expected=2700.0, predicted=2735.5
# >expected=2658.2, predicted=2681.6
# >expected=2634.9, predicted=2647.2
# >expected=2642.1, predicted=2625.0
# >expected=2663.6, predicted=2647.4
# >expected=2680.1, predicted=2688.8
# >expected=2674.0, predicted=2695.5
# >expected=2694.5, predicted=2674.6
# >expected=2719.4, predicted=2695.4
# >expected=2755.5, predicted=2710.2
# >expected=2750.9, predicted=2750.6
# >expected=2739.8, predicted=2743.2
# >expected=2722.7, predicted=2725.6
# >expected=2713.9, predicted=2737.7
# >expected=2714.7, predicted=2714.6
# >expected=2709.0, predicted=2721.1
# >expected=2686.8, predicted=2696.2
# >expected=2680.9, predicted=2688.2
# >expected=2680.1, predicted=2683.1
# >expected=2630.4, predicted=2688.5
# >expected=2586.0, predicted=2610.0
# >expected=2565.3, predicted=2607.1
# >expected=2597.4, predicted=2581.7
# >expected=2608.0, predicted=2594.7
# >expected=2569.0, predicted=2617.4
# >expected=2582.4, predicted=2604.1
# >expected=2595.3, predicted=2598.0
# >expected=2946.3, predicted=2937.5
# >expected=2949.9, predicted=2936.7
# >expected=2954.3, predicted=2952.0
# >expected=2958.1, predicted=2948.1
# >expected=2958.9, predicted=2951.7
# >expected=2951.1, predicted=2938.8
# >expected=2937.7, predicted=2950.4
# >expected=2907.8, predicted=2924.2
# >expected=2871.0, predicted=2912.0
# >expected=2852.3, predicted=2858.4
# >expected=2791.8, predicted=2842.0
# >expected=2795.0, predicted=2764.9
# >expected=2809.0, predicted=2792.9
# >expected=2848.8, predicted=2806.7
# >expected=2857.4, predicted=2845.6
# >expected=2857.3, predicted=2871.9
# >expected=2833.5, predicted=2846.3
# >expected=2844.9, predicted=2833.1
# >expected=2812.7, predicted=2847.3
# >expected=2788.0, predicted=2811.8
# >expected=2814.1, predicted=2769.9
# >expected=2840.8, predicted=2815.6
# >expected=2856.4, predicted=2841.1
# >expected=2850.2, predicted=2845.8
# >expected=2858.5, predicted=2851.1
# >expected=2861.6, predicted=2858.9
# >expected=2839.0, predicted=2859.9
# >expected=2766.5, predicted=2842.3
# >expected=2806.0, predicted=2734.8
# >expected=2812.6, predicted=2825.7
# >expected=2813.3, predicted=2842.0
# >expected=2852.7, predicted=2805.2
# >expected=2868.0, predicted=2844.3
# >expected=2845.5, predicted=2880.2
# >expected=2845.6, predicted=2846.0
# >expected=2841.5, predicted=2844.7
# >expected=2872.8, predicted=2840.5
# >expected=2907.2, predicted=2877.1
# >expected=2916.1, predicted=2908.2
# >expected=2920.4, predicted=2927.3
# >expected=2918.7, predicted=2934.0
# >expected=2908.1, predicted=2911.3
# >expected=2929.6, predicted=2896.9
# >expected=2947.4, predicted=2943.3
# >expected=2950.8, predicted=2949.0
# >expected=2926.2, predicted=2953.3
# >expected=2932.7, predicted=2935.4
# >expected=2935.6, predicted=2935.3
# >expected=2937.2, predicted=2932.1
# >expected=2943.0, predicted=2935.3
# >expected=2942.3, predicted=2938.1
# >expected=2936.4, predicted=2945.0
# >expected=2931.0, predicted=2931.8
# >expected=2921.9, predicted=2933.5
# >expected=2909.7, predicted=2918.0
# >expected=2915.1, predicted=2915.4
# >expected=2911.2, predicted=2927.6
# >expected=2906.9, predicted=2930.7
# >expected=2912.9, predicted=2916.0
# >expected=2898.5, predicted=2923.4
# >expected=2838.3, predicted=2894.9
# >expected=2830.8, predicted=2834.7
# >expected=2855.9, predicted=2811.8
# >expected=2872.2, predicted=2867.9
# >expected=2876.6, predicted=2900.9
# >expected=2847.5, predicted=2879.7
# >expected=2844.3, predicted=2842.6
# >expected=2866.3, predicted=2849.1
# >expected=2904.5, predicted=2891.3
# >expected=2911.8, predicted=2915.0
# >expected=2902.7, predicted=2917.6
# >expected=2921.5, predicted=2912.9
# >expected=2924.2, predicted=2910.8
# >expected=2930.6, predicted=2920.6
# >expected=2926.9, predicted=2930.0
# >expected=2927.4, predicted=2934.6
# >expected=2935.4, predicted=2938.0
# >expected=2936.1, predicted=2942.2
# >expected=2931.7, predicted=2940.4
# >expected=2940.1, predicted=2936.4
# >expected=2946.2, predicted=2943.6
# >expected=2958.6, predicted=2944.3
# >expected=2967.8, predicted=2952.7
# >expected=2970.3, predicted=2957.7
# >expected=2973.3, predicted=2952.8
# >expected=2971.9, predicted=2952.9
# >expected=2985.5, predicted=2942.8
# >expected=3003.0, predicted=2973.4
# >expected=3011.5, predicted=3001.9
# >expected=3010.2, predicted=3008.5
# >expected=3006.3, predicted=3010.1
# >expected=3019.9, predicted=3006.1
# >expected=3017.6, predicted=3015.1
# >expected=3018.8, predicted=3015.6
# >expected=3016.6, predicted=3018.5
# >expected=3023.7, predicted=3017.8
# >expected=3022.5, predicted=3020.2
# >expected=3029.3, predicted=3020.4
# >expected=3043.4, predicted=3024.2
# >expected=3050.5, predicted=3038.0
# >expected=3054.9, predicted=3048.6
# >expected=3054.8, predicted=3053.7
# >expected=3040.7, predicted=3054.1
# >expected=3038.9, predicted=3041.6
# >expected=3042.6, predicted=3039.4
# >expected=3053.3, predicted=3043.1
# >expected=3061.0, predicted=3053.3
# >expected=3071.6, predicted=3056.5
# >expected=3081.5, predicted=3050.9
# >expected=3081.6, predicted=3069.6
# >expected=3079.6, predicted=3080.9
# >expected=3086.2, predicted=3079.5
# >expected=3065.0, predicted=3083.2
# >expected=3030.7, predicted=3069.3
# >expected=3041.0, predicted=3030.7
# >expected=3051.1, predicted=3035.4
# >expected=3069.8, predicted=3039.3
# >expected=3076.0, predicted=3070.5
# >expected=3074.7, predicted=3075.7
# >expected=3067.0, predicted=3071.8
# >expected=3073.7, predicted=3071.4
# >expected=3095.4, predicted=3069.6
# >expected=3109.2, predicted=3071.0
# >expected=3113.2, predicted=3089.0
# >expected=3124.2, predicted=3106.9
# >expected=3128.4, predicted=3094.3
# >expected=3128.8, predicted=3127.3
# >expected=3136.2, predicted=3123.7
# >expected=3149.2, predicted=3135.1
# >expected=3159.2, predicted=3148.0
# >expected=3159.4, predicted=3158.1
# >expected=3158.9, predicted=3158.6
# >expected=3160.8, predicted=3158.8
# >expected=3168.5, predicted=3159.4
# >expected=3177.8, predicted=3167.2
# >expected=3173.9, predicted=3176.6
# >expected=3163.1, predicted=3176.6
# >expected=3154.9, predicted=3173.7
# >expected=3170.4, predicted=3157.1
# >expected=3178.7, predicted=3170.3
# >expected=3162.4, predicted=3175.0
# >expected=3154.8, predicted=3162.3
# >expected=3163.7, predicted=3165.3
# >expected=3166.2, predicted=3169.4
# >expected=3180.0, predicted=3175.2
# >expected=3205.0, predicted=3166.9
# >expected=3210.0, predicted=3163.1
# >expected=3202.7, predicted=3198.5
# >expected=3213.2, predicted=3204.8
# >expected=3216.4, predicted=3211.7
# >expected=3221.6, predicted=3214.5
# >expected=3240.5, predicted=3218.8
# >expected=3254.9, predicted=3238.7
# >expected=3258.1, predicted=3239.2
# >expected=3252.5, predicted=3256.4
# >expected=3251.5, predicted=3252.8
# >expected=3258.1, predicted=3251.5
# >expected=3251.0, predicted=3257.2
# >expected=3249.9, predicted=3251.2
# >expected=3194.5, predicted=3252.0
# >expected=3181.1, predicted=3248.2
# >expected=3201.3, predicted=3184.0
# >expected=3209.3, predicted=3208.7
# >expected=2801.7, predicted=2818.8
# >expected=2823.9, predicted=2810.2
# >expected=2854.9, predicted=2831.2
# >expected=2881.4, predicted=2851.6
# >expected=2859.7, predicted=2839.9
# >expected=2835.0, predicted=2855.1
# >expected=2776.7, predicted=2810.5
# >expected=2760.8, predicted=2794.8
# >expected=2783.7, predicted=2769.3
# >expected=2815.1, predicted=2791.6
# >expected=2867.6, predicted=2836.1
# >expected=2882.0, predicted=2861.1
# >expected=2897.5, predicted=2844.2
# >expected=2889.2, predicted=2853.5
# >expected=2874.7, predicted=2893.6
# >expected=2906.1, predicted=2879.2
# >expected=2926.0, predicted=2924.5
# >expected=2946.8, predicted=2924.5
# >expected=2963.4, predicted=2944.2
# >expected=2981.7, predicted=2968.3
# >expected=2967.7, predicted=2973.6
# >expected=2977.1, predicted=2952.6
# >expected=2986.6, predicted=2950.7
# >expected=3010.3, predicted=2960.9
# >expected=3046.7, predicted=3017.6
# >expected=3053.1, predicted=3009.2
# >expected=3105.7, predicted=3042.0
# >expected=3139.8, predicted=3092.6
# >expected=3152.3, predicted=3159.2
# >expected=3153.3, predicted=3154.7
# >expected=3137.4, predicted=3161.1
# >expected=3019.4, predicted=3152.2
# >expected=2986.3, predicted=3007.4
# >expected=2938.9, predicted=2914.2
# >expected=2969.9, predicted=2915.4
# >expected=3062.6, predicted=2978.1
# >expected=3064.8, predicted=3114.9
# >expected=3053.3, predicted=3055.2
# >expected=3062.6, predicted=3051.9
# >expected=3016.7, predicted=3097.9
# >expected=3049.0, predicted=3024.7
# >expected=3077.6, predicted=3052.9
# >expected=3021.2, predicted=3073.2
# >expected=3001.1, predicted=3051.8
# >expected=2996.1, predicted=2957.3
# >expected=2958.6, predicted=2966.0
# >expected=2981.5, predicted=2941.0
# >expected=3015.1, predicted=3013.1
# >expected=3048.1, predicted=3050.2
# >expected=3080.4, predicted=3054.7
# >expected=3073.6, predicted=3056.2
# >expected=3100.2, predicted=3069.9
# >expected=3120.2, predicted=3131.2
# >expected=3103.6, predicted=3120.9
# >expected=3102.7, predicted=3097.2
# >expected=3100.8, predicted=3126.5
# >expected=3095.4, predicted=3122.2
# >expected=3144.9, predicted=3120.5
# >expected=3136.9, predicted=3161.6
# >expected=3124.7, predicted=3110.5
# >expected=3165.5, predicted=3118.8
# >expected=3153.0, predicted=3165.7
# >expected=3161.5, predicted=3157.3
# >expected=3163.3, predicted=3170.1
# >expected=3178.2, predicted=3159.5
# >expected=3214.5, predicted=3178.3
# >expected=3207.8, predicted=3210.3
# >expected=3206.3, predicted=3207.7
# >expected=3164.1, predicted=3209.1
# >expected=3164.5, predicted=3156.4
# >expected=3179.0, predicted=3168.6
# >expected=3176.9, predicted=3202.7
# >expected=3186.9, predicted=3178.8
# >expected=3191.6, predicted=3204.5
# >expected=3200.9, predicted=3181.6
# >expected=3217.6, predicted=3214.5
# >expected=3233.9, predicted=3230.4
# >expected=3243.2, predicted=3237.6
# >expected=3270.1, predicted=3238.9
# >expected=3279.2, predicted=3267.4
# >expected=3288.1, predicted=3279.7
# >expected=3297.0, predicted=3310.9
# >expected=3304.5, predicted=3311.3
# >expected=3308.6, predicted=3312.6
# >expected=3315.0, predicted=3314.3
# >expected=3324.2, predicted=3315.2
# >expected=3319.0, predicted=3309.4
# >expected=3323.6, predicted=3302.3
# >expected=3330.3, predicted=3296.2
# >expected=3337.8, predicted=3296.2
# >expected=3333.4, predicted=3305.9
# >expected=3325.5, predicted=3319.3
# >expected=3336.0, predicted=3333.1
# >expected=3352.8, predicted=3330.1
# >expected=3374.8, predicted=3348.9
# >expected=3392.2, predicted=3373.5
# >expected=3411.6, predicted=3354.0
# >expected=3437.2, predicted=3364.8
# >expected=3450.0, predicted=3427.3
# >expected=3473.5, predicted=3448.4
# >expected=3458.8, predicted=3471.9
# >expected=3469.5, predicted=3459.1
# >expected=3511.9, predicted=3458.8
# >expected=3457.3, predicted=3500.3
# >expected=3391.7, predicted=3508.7
# >expected=3363.5, predicted=3433.5
# >expected=3377.0, predicted=3368.5
# >expected=3323.1, predicted=3367.9
# >expected=3334.7, predicted=3365.5
# >expected=3329.0, predicted=3354.2
# >expected=3304.6, predicted=3343.4
# >expected=3318.1, predicted=3318.0
# >expected=3335.2, predicted=3326.5
# >expected=3358.2, predicted=3309.1
# >expected=3354.7, predicted=3351.6
# >expected=3303.0, predicted=3358.1
# >expected=3298.9, predicted=3295.0
# >expected=3276.8, predicted=3323.0
# >expected=3228.9, predicted=3247.8
# >expected=3246.1, predicted=3182.0
# >expected=3235.7, predicted=3223.1
# >expected=3198.8, predicted=3202.6
# >expected=3212.6, predicted=3183.7
# >expected=3260.5, predicted=3191.8
# >expected=3298.8, predicted=3264.6
# >expected=3300.6, predicted=3303.5
# >expected=3304.9, predicted=3289.4
# >expected=3333.5, predicted=3325.5
# >expected=3295.2, predicted=3324.1
# >expected=3324.7, predicted=3285.9
# >expected=3340.5, predicted=3315.8
# >expected=3339.6, predicted=3351.0
# >expected=3356.0, predicted=3335.6
# >expected=3397.9, predicted=3325.8
# >expected=3421.7, predicted=3405.5
# >expected=3436.4, predicted=3438.0
# >expected=3471.3, predicted=3451.7
# >expected=3478.2, predicted=3465.0
# >expected=3457.5, predicted=3467.2
# >expected=3427.7, predicted=3468.4
# >expected=3447.1, predicted=3467.0
# >expected=3444.6, predicted=3462.6
# >expected=3425.4, predicted=3411.2
# >expected=3406.4, predicted=3428.0
# >expected=3395.3, predicted=3425.4
# >expected=3397.2, predicted=3410.3
# >expected=3413.9, predicted=3392.9
# >expected=3398.1, predicted=3426.2
# >expected=3367.3, predicted=3417.8
# >expected=3350.2, predicted=3371.8
# >expected=3272.4, predicted=3323.3
# >expected=3248.5, predicted=3247.2
# >expected=3221.7, predicted=3219.3
# >expected=3227.2, predicted=3212.3
# >expected=3264.0, predicted=3232.3
# >expected=3317.8, predicted=3283.5
# >expected=3386.9, predicted=3309.1
# >expected=3458.1, predicted=3370.9
# >expected=3452.7, predicted=3476.0
# >expected=3514.8, predicted=3451.2
# >expected=3535.9, predicted=3464.2
# >expected=3502.6, predicted=3416.3
# >expected=3524.6, predicted=3455.8
# >expected=3505.9, predicted=3411.7
# >expected=3523.6, predicted=3449.0
# >expected=3571.0, predicted=3487.4
# >expected=3577.7, predicted=3559.2
# >expected=3568.6, predicted=3547.7
# >expected=3554.1, predicted=3544.0
# >expected=3523.7, predicted=3554.0
# >expected=3531.3, predicted=3524.1
# >expected=3526.5, predicted=3531.3
# >expected=3542.0, predicted=3545.3
# >expected=3585.2, predicted=3539.0
# >expected=3593.0, predicted=3576.2
# >expected=3588.2, predicted=3570.6
# >expected=3598.4, predicted=3569.9
# >expected=3592.9, predicted=3545.3
# >expected=3589.7, predicted=3567.3
# >expected=3621.9, predicted=3567.5
# >expected=3623.1, predicted=3614.2
# >expected=3632.2, predicted=3616.5
# >expected=3645.3, predicted=3624.6
# >expected=3656.3, predicted=3631.8
# >expected=3648.7, predicted=3654.7
# >expected=3655.7, predicted=3648.3
# >expected=3654.2, predicted=3654.9
# >expected=3631.8, predicted=3654.2
# >expected=3615.2, predicted=3634.1
# >expected=3643.9, predicted=3616.2
# >expected=3634.5, predicted=3622.9
# >expected=3642.3, predicted=3634.4
# >expected=3666.0, predicted=3647.1
# >expected=3681.5, predicted=3651.5
# >expected=3676.7, predicted=3660.5
# >expected=3673.9, predicted=3669.3
# >expected=3643.2, predicted=3657.0
# >expected=3649.3, predicted=3622.4
# >expected=3658.9, predicted=3646.1
# >expected=3660.8, predicted=3642.3
# >expected=3683.0, predicted=3669.7
# >expected=3698.4, predicted=3681.6
# >expected=3704.7, predicted=3662.9
# >expected=3700.7, predicted=3682.0
# >expected=3697.6, predicted=3687.5
# >expected=3718.5, predicted=3695.6
# >expected=3692.9, predicted=3701.7
# >expected=3672.6, predicted=3707.3
# >expected=3706.6, predicted=3664.6
# >expected=3755.6, predicted=3681.0
# >expected=3779.4, predicted=3680.7
# >expected=3772.8, predicted=3692.4
# >expected=3767.7, predicted=3761.9
# >expected=3767.7, predicted=3714.9
# >expected=3773.4, predicted=3777.9
# >expected=3773.2, predicted=3773.3
# >expected=3741.7, predicted=3773.2
# >expected=3725.1, predicted=3745.7
# >expected=3739.2, predicted=3728.1
# >expected=3762.2, predicted=3739.2
# >expected=3799.1, predicted=3744.5
# >expected=3818.6, predicted=3772.0
# >expected=3801.6, predicted=3792.3
# >expected=3818.7, predicted=3768.5
# >expected=3811.2, predicted=3799.2
# >expected=3814.0, predicted=3813.2
# >expected=3752.5, predicted=3784.5
# >expected=3732.0, predicted=3747.4
# >expected=3705.0, predicted=3727.8
# >expected=3671.7, predicted=3713.8
# >expected=3725.4, predicted=3683.4
# >expected=3786.4, predicted=3756.3
# >expected=3801.6, predicted=3777.2
# >expected=3818.0, predicted=3794.9
# >expected=3850.9, predicted=3808.0
# >expected=3868.1, predicted=3818.3
# >expected=3870.9, predicted=3842.3
# >expected=3880.1, predicted=3816.6
# >expected=3881.7, predicted=3813.5
# >expected=3879.7, predicted=3810.2
# >expected=3881.6, predicted=3872.4
# >expected=3915.2, predicted=3878.5
# >expected=3921.7, predicted=3905.7
# >expected=3908.3, predicted=3920.2
# >expected=3895.2, predicted=3918.5
# >expected=3878.3, predicted=3913.9
# >expected=3885.8, predicted=3881.5
# >expected=3871.7, predicted=3889.2
# >expected=3852.9, predicted=3895.3
# >expected=3837.1, predicted=3868.5
# >expected=3871.0, predicted=3833.8
# >expected=3844.5, predicted=3873.9
# >expected=3796.3, predicted=3845.7
# >expected=3811.2, predicted=3791.8
# >expected=3847.4, predicted=3786.1
# >expected=3854.0, predicted=3794.9
# >expected=3819.1, predicted=3842.8
# >expected=3755.2, predicted=3831.6
# >expected=3754.4, predicted=3769.6
# >expected=3812.9, predicted=3718.7
# >expected=3806.8, predicted=3815.5
# >expected=3839.9, predicted=3772.8
# >expected=3864.3, predicted=3822.2
# >expected=3906.1, predicted=3864.0
# >expected=3898.9, predicted=3876.5
# >expected=3921.8, predicted=3874.8
# >expected=3924.8, predicted=3908.0
# >expected=3939.1, predicted=3918.1
# >expected=3934.8, predicted=3909.1
# >expected=3916.2, predicted=3889.5
# >expected=3891.2, predicted=3915.7
# >expected=3877.1, predicted=3868.4
# >expected=3900.5, predicted=3877.2
# >expected=3894.7, predicted=3900.8
# >expected=3882.1, predicted=3875.5
# >expected=3871.2, predicted=3879.3
# >expected=3906.2, predicted=3880.7
# >expected=3929.1, predicted=3895.7
# >expected=3933.4, predicted=3914.0
# >expected=3932.7, predicted=3914.1
# >expected=3943.8, predicted=3928.5
# >expected=3977.2, predicted=3923.5
# >expected=4003.3, predicted=3936.3
# >expected=4009.9, predicted=3974.3
# >expected=4032.3, predicted=4008.0
# >expected=4046.6, predicted=4030.7
# >expected=4051.6, predicted=4044.3
# >expected=4069.5, predicted=4050.0
# >expected=4078.3, predicted=4067.9
# >expected=4092.0, predicted=4076.7
# >expected=4096.5, predicted=4090.4
# >expected=4106.5, predicted=4094.7
# >expected=4111.9, predicted=4104.9
# >expected=4129.9, predicted=4110.3
# >expected=4148.3, predicted=4128.4
# >expected=4148.8, predicted=4146.6
# >expected=4143.9, predicted=4147.9
# >expected=4115.7, predicted=4144.1
# >expected=4123.6, predicted=4116.5
# >expected=4130.1, predicted=4131.5
# >expected=4131.9, predicted=4126.7
# >expected=4152.8, predicted=4132.2
# >expected=4158.4, predicted=4136.1
# >expected=4162.4, predicted=4138.8
# >expected=4166.6, predicted=4141.5
# >expected=4178.6, predicted=4164.8
# >expected=4164.6, predicted=4160.1
# >expected=4169.9, predicted=4164.9
# >expected=4168.6, predicted=4171.6
# >expected=4142.8, predicted=4168.6
# >expected=4148.5, predicted=4142.0
# >expected=4156.3, predicted=4147.2
# >expected=4193.1, predicted=4152.9
# >expected=4214.5, predicted=4178.0
# >expected=4186.9, predicted=4195.8
# >expected=4124.7, predicted=4173.3
# >expected=4078.2, predicted=4137.8
# >expected=4070.5, predicted=4094.6
# >expected=4127.8, predicted=4087.2
# >expected=4146.5, predicted=4155.3
# >expected=4139.1, predicted=4163.8
# >expected=4127.1, predicted=4133.5
# >expected=4076.4, predicted=4137.1
# >expected=4116.2, predicted=4124.6
# >expected=4144.9, predicted=4128.5
# >expected=4139.6, predicted=4146.0
# >expected=4168.1, predicted=4141.3
# >expected=4179.7, predicted=4150.4
# >expected=4174.7, predicted=4158.7
# >expected=4180.2, predicted=4163.1
# >expected=4191.9, predicted=4165.9
# >expected=4188.9, predicted=4156.9
# >expected=4180.1, predicted=4176.8
# >expected=4188.0, predicted=4124.7
# >expected=4185.4, predicted=4168.3
# >expected=4173.4, predicted=4186.7
# >expected=4188.3, predicted=4170.0
# >expected=4205.5, predicted=4188.8
# >expected=4205.3, predicted=4196.3
# >expected=4208.0, predicted=4193.8
# >expected=4207.8, predicted=4154.4
# >expected=4213.8, predicted=4164.5
# >expected=4222.3, predicted=4204.6
# >expected=4231.4, predicted=4175.4
# >expected=4230.6, predicted=4197.1
# >expected=4233.5, predicted=4230.3
# >expected=4211.8, predicted=4214.1
# >expected=4198.1, predicted=4211.4
# >expected=4179.1, predicted=4199.2
# >expected=4132.8, predicted=4155.8
# >expected=4182.4, predicted=4103.2
# >expected=4216.8, predicted=4157.7
# >expected=4230.1, predicted=4212.6
# >expected=4244.8, predicted=4208.5
# >expected=4254.9, predicted=4204.9
# >expected=4265.8, predicted=4208.7
# >expected=4264.9, predicted=4249.9
# >expected=4273.4, predicted=4247.1
# >expected=4277.3, predicted=4268.4
# >expected=4293.5, predicted=4276.8
# >expected=4314.3, predicted=4291.3
# >expected=4328.6, predicted=4295.9
# >expected=4332.4, predicted=4327.1
# >expected=4323.3, predicted=4330.2
# >expected=4333.0, predicted=4323.2
# >expected=4299.4, predicted=4324.1
# >expected=4327.5, predicted=4309.0
# >expected=4348.6, predicted=4307.1
# >expected=4355.8, predicted=4316.9
# >expected=4359.5, predicted=4350.0
# >expected=4355.1, predicted=4351.7
# >expected=4343.3, predicted=4308.6
# >expected=4337.3, predicted=4353.9
# >expected=4295.0, predicted=4337.7
# >expected=4258.6, predicted=4301.7
# >expected=4288.2, predicted=4263.5
# >expected=4330.1, predicted=4304.2
# >expected=4350.8, predicted=4328.8
# >expected=4375.8, predicted=4356.5
# >expected=4385.5, predicted=4328.8
# >expected=4392.4, predicted=4351.1
# >expected=4384.9, predicted=4372.0
# >expected=4384.1, predicted=4377.3
# >expected=4390.3, predicted=4333.1
# >expected=4376.4, predicted=4369.5
# >expected=4400.7, predicted=4378.5
# >expected=4389.4, predicted=4388.7
# >expected=4390.2, predicted=4395.5
# >expected=4394.7, predicted=4391.1
# >expected=4401.3, predicted=4380.0
# >expected=4415.4, predicted=4384.9
# >expected=4409.8, predicted=4393.2
# >expected=4413.8, predicted=4409.1
# >expected=4418.2, predicted=4413.7
# >expected=4424.7, predicted=4416.5
# >expected=4436.7, predicted=4419.7
# >expected=4448.6, predicted=4434.9
# >expected=4444.2, predicted=4446.9
# >expected=4447.5, predicted=4447.1
# >expected=4435.5, predicted=4447.2
# >expected=4414.5, predicted=4437.1
# >expected=4376.9, predicted=4414.7
# >expected=4398.8, predicted=4392.6
# >expected=4436.6, predicted=4386.5
# >expected=4459.9, predicted=4443.1
# >expected=4474.1, predicted=4437.8
# >expected=4478.4, predicted=4446.5
# >expected=4469.8, predicted=4446.4
# >expected=4480.2, predicted=4460.3
# >expected=4497.6, predicted=4439.7
# >expected=4511.7, predicted=4493.1
# >expected=4519.1, predicted=4510.6
# >expected=4519.5, predicted=4514.1
# >expected=4523.9, predicted=4518.4
# >expected=4528.5, predicted=4521.5
# >expected=4520.5, predicted=4526.8
# >expected=4532.8, predicted=4520.7
# >expected=4517.8, predicted=4524.3
# >expected=4500.1, predicted=4529.4
# >expected=4492.0, predicted=4501.0
# >expected=4486.8, predicted=4491.7
# >expected=4458.8, predicted=4492.8
# >expected=4463.3, predicted=4476.0
# >expected=4449.9, predicted=4484.5
# >expected=4456.4, predicted=4444.7
# >expected=4461.5, predicted=4457.6
# >expected=4445.0, predicted=4460.2
# >expected=4402.9, predicted=4433.0
# >expected=4355.1, predicted=4379.5
# >expected=4359.6, predicted=4367.7
# >expected=4378.8, predicted=4351.7
# >expected=4428.1, predicted=4381.1
# >expected=4431.9, predicted=4433.9
# >expected=4459.8, predicted=4436.6
# >expected=4440.4, predicted=4435.9
# >expected=4377.3, predicted=4419.7
# >expected=4366.1, predicted=4386.1
# >expected=4334.1, predicted=4368.6
# >expected=4304.2, predicted=4353.6
# MAE: 21.859
# 2023-06-17 00:15:19 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:15:19 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:15:19 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:15:19 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:15:19 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 1170
# 1170
# COLUMN: NQ -------------------------
# Datetime
# 2007-08-20    1982.00000
# 2007-08-21    1994.65625
# Name: NQ, dtype: float64
# >expected=6548.7, predicted=6483.3
# >expected=6605.7, predicted=6544.5
# >expected=6690.5, predicted=6595.9
# >expected=6732.5, predicted=6680.8
# >expected=6765.6, predicted=6657.6
# >expected=6803.3, predicted=6701.0
# >expected=6808.8, predicted=6732.9
# >expected=6820.2, predicted=6779.4
# >expected=6797.1, predicted=6778.6
# >expected=6831.9, predicted=6796.8
# >expected=6875.0, predicted=6823.6
# >expected=6920.4, predicted=6869.8
# >expected=6913.9, predicted=6915.5
# >expected=6915.5, predicted=6913.7
# >expected=6928.9, predicted=6917.3
# >expected=6948.0, predicted=6920.8
# >expected=6963.9, predicted=6945.7
# >expected=6969.0, predicted=6962.1
# >expected=7016.7, predicted=6967.1
# >expected=7087.2, predicted=7014.8
# >expected=7085.5, predicted=7084.3
# >expected=7077.7, predicted=7085.0
# >expected=7107.2, predicted=7077.3
# >expected=7169.3, predicted=7103.0
# >expected=7135.2, predicted=7165.5
# >expected=7080.4, predicted=7134.8
# >expected=7096.9, predicted=7138.5
# >expected=7082.8, predicted=7113.8
# >expected=6986.9, predicted=7080.1
# >expected=6865.6, predicted=6987.8
# >expected=6748.3, predicted=6960.1
# >expected=6664.9, predicted=6811.1
# >expected=6730.1, predicted=6566.2
# >expected=6593.4, predicted=6738.8
# >expected=6476.3, predicted=6738.8
# >expected=6574.2, predicted=6374.6
# >expected=6633.8, predicted=6551.1
# >expected=6660.6, predicted=6693.8
# >expected=6762.7, predicted=6682.4
# >expected=6897.0, predicted=6803.1
# >expected=6950.0, predicted=6898.4
# >expected=6939.1, predicted=6925.8
# >expected=6923.7, predicted=6937.7
# >expected=6916.6, predicted=6919.2
# >expected=6916.5, predicted=6947.4
# >expected=6906.1, predicted=6933.8
# >expected=6964.0, predicted=6919.9
# >expected=7032.8, predicted=6968.1
# >expected=7090.5, predicted=7097.7
# >expected=7084.4, predicted=7086.6
# >expected=7038.6, predicted=7080.2
# >expected=6942.9, predicted=7093.9
# >expected=6873.6, predicted=6959.5
# >expected=6915.4, predicted=6863.8
# >expected=6971.0, predicted=6898.2
# >expected=7021.5, predicted=7000.9
# >expected=7017.9, predicted=7073.2
# >expected=7090.3, predicted=7052.0
# >expected=7154.6, predicted=6933.8
# >expected=7259.4, predicted=7128.8
# >expected=7267.8, predicted=7136.6
# >expected=7226.2, predicted=7148.5
# >expected=7182.5, predicted=7147.2
# >expected=7171.5, predicted=7103.0
# >expected=7164.2, predicted=7075.6
# >expected=7125.5, predicted=7099.3
# >expected=7025.9, predicted=7057.2
# >expected=7011.1, predicted=6967.6
# >expected=7004.0, predicted=6992.3
# >expected=6857.2, predicted=6979.9
# >expected=6736.3, predicted=6759.4
# >expected=6689.5, predicted=6668.0
# >expected=6801.5, predicted=6686.2
# >expected=6815.0, predicted=6755.9
# >expected=6612.2, predicted=6755.6
# >expected=6643.8, predicted=6659.3
# >expected=6670.6, predicted=6694.4
# >expected=6572.5, predicted=6740.6
# >expected=6540.8, predicted=6516.6
# >expected=6583.4, predicted=6590.2
# >expected=6701.1, predicted=6609.6
# >expected=6628.8, predicted=6742.4
# >expected=6599.5, predicted=6617.7
# >expected=6636.3, predicted=6624.9
# >expected=6704.9, predicted=6620.3
# >expected=6709.8, predicted=6674.0
# >expected=6749.8, predicted=6709.6
# >expected=6768.9, predicted=6755.2
# >expected=6781.7, predicted=6855.5
# >expected=6793.3, predicted=6783.2
# >expected=6897.3, predicted=6821.9
# >expected=6954.5, predicted=6997.5
# >expected=6909.4, predicted=6933.3
# >expected=6836.8, predicted=6918.3
# >expected=6800.2, predicted=6817.3
# >expected=6782.2, predicted=6830.6
# >expected=6705.3, predicted=6845.7
# >expected=6638.4, predicted=6654.5
# >expected=6757.7, predicted=6600.7
# >expected=6813.8, predicted=6769.0
# >expected=6795.0, predicted=6818.1
# >expected=6763.6, predicted=6821.0
# >expected=6751.6, predicted=6869.2
# >expected=6783.0, predicted=6816.7
# >expected=6741.4, predicted=6797.6
# >expected=6802.7, predicted=6775.9
# >expected=6909.2, predicted=6873.1
# >expected=6930.0, predicted=6885.8
# >expected=6918.6, predicted=6925.0
# >expected=6969.4, predicted=6905.9
# >expected=7044.1, predicted=6980.5
# >expected=7066.2, predicted=7073.4
# >expected=7091.3, predicted=7087.6
# >expected=7083.6, predicted=7119.3
# >expected=7014.6, predicted=7064.7
# >expected=7025.6, predicted=6997.3
# >expected=7024.0, predicted=7020.3
# >expected=7007.3, predicted=7025.8
# >expected=7035.2, predicted=6989.3
# >expected=7023.8, predicted=7031.4
# >expected=7020.3, predicted=7041.3
# >expected=7003.1, predicted=7042.9
# >expected=7062.0, predicted=6975.9
# >expected=7078.5, predicted=7061.1
# >expected=7098.4, predicted=7064.6
# >expected=7093.7, predicted=7119.4
# >expected=7041.3, predicted=7082.5
# >expected=7077.3, predicted=7027.1
# >expected=7095.1, predicted=7086.2
# >expected=7143.3, predicted=7049.4
# >expected=7200.1, predicted=7091.5
# >expected=7234.2, predicted=7197.0
# >expected=7274.1, predicted=7181.5
# >expected=7302.7, predicted=7197.7
# >expected=7285.8, predicted=7259.8
# >expected=7233.3, predicted=7262.6
# >expected=7248.8, predicted=7241.7
# >expected=7269.8, predicted=7217.0
# >expected=7302.8, predicted=7206.9
# >expected=7328.0, predicted=7288.4
# >expected=7354.5, predicted=7230.9
# >expected=7370.4, predicted=7270.2
# >expected=7337.6, predicted=7362.1
# >expected=7325.0, predicted=7339.6
# >expected=7300.6, predicted=7326.1
# >expected=7384.8, predicted=7286.3
# >expected=7359.0, predicted=7356.7
# >expected=7325.8, predicted=7332.9
# >expected=7283.3, predicted=7309.4
# >expected=7185.4, predicted=7322.1
# >expected=7171.6, predicted=7144.4
# >expected=7133.5, predicted=7166.3
# >expected=7115.6, predicted=7060.2
# >expected=7174.9, predicted=7075.1
# >expected=7153.0, predicted=7177.7
# >expected=7143.3, predicted=7130.2
# >expected=7162.8, predicted=7083.3
# >expected=7120.8, predicted=7155.4
# >expected=7168.1, predicted=7046.0
# >expected=7246.8, predicted=7155.7
# >expected=7335.5, predicted=7223.5
# >expected=7363.9, predicted=7286.5
# >expected=7371.5, predicted=7338.2
# >expected=7335.9, predicted=7321.0
# >expected=7424.1, predicted=7297.7
# >expected=7476.7, predicted=7319.6
# >expected=7486.4, predicted=7409.0
# >expected=7454.5, predicted=7416.2
# ...
# >expected=5577.3, predicted=5552.5
# >expected=5711.3, predicted=5612.3
# >expected=5712.0, predicted=5738.9
# >expected=5742.1, predicted=5704.4
# >expected=5738.5, predicted=5651.0
# >expected=5690.0, predicted=5693.7
# >expected=5724.5, predicted=5688.8
# >expected=5740.0, predicted=5705.7
# >expected=5793.0, predicted=5711.0
# >expected=5867.2, predicted=5845.8
# >expected=5910.4, predicted=5875.3
# >expected=5843.0, predicted=5913.4
# >expected=5838.0, predicted=5814.1
# >expected=5878.8, predicted=5829.3
# >expected=5945.2, predicted=5855.0
# >expected=6058.7, predicted=5910.6
# >expected=6066.2, predicted=6062.7
# >expected=6149.4, predicted=6094.1
# >expected=6177.8, predicted=6147.4
# >expected=6197.5, predicted=6223.6
# >expected=6081.1, predicted=6200.7
# >expected=6032.0, predicted=6106.7
# >expected=5809.0, predicted=6043.9
# >expected=5824.4, predicted=5841.5
# >expected=5805.1, predicted=5842.7
# >expected=5799.8, predicted=5810.1
# >expected=5951.1, predicted=5791.5
# >expected=5962.5, predicted=5997.4
# >expected=5940.8, predicted=5962.1
# >expected=5985.5, predicted=5981.7
# >expected=5958.2, predicted=5979.8
# >expected=5986.4, predicted=5996.4
# >expected=6018.5, predicted=6007.3
# >expected=5883.7, predicted=6002.1
# >expected=5877.2, predicted=5899.0
# >expected=5919.3, predicted=5871.6
# >expected=5868.3, predicted=5926.4
# >expected=5926.3, predicted=5894.9
# >expected=5906.7, predicted=5887.2
# >expected=5891.0, predicted=5874.7
# >expected=5953.4, predicted=5913.6
# >expected=5912.3, predicted=5974.9
# >expected=5935.3, predicted=5884.3
# >expected=5996.0, predicted=5962.3
# >expected=5916.4, predicted=5969.7
# >expected=5897.3, predicted=5913.0
# >expected=5829.0, predicted=5927.0
# >expected=5808.1, predicted=5847.3
# >expected=5868.3, predicted=5837.3
# >expected=5870.8, predicted=5910.4
# >expected=5899.8, predicted=5864.3
# >expected=6000.1, predicted=5891.8
# >expected=5991.2, predicted=5943.9
# >expected=6003.7, predicted=5959.6
# >expected=6014.5, predicted=6018.0
# >expected=5992.6, predicted=6019.5
# >expected=6000.6, predicted=6002.6
# >expected=5944.3, predicted=6024.0
# >expected=5928.4, predicted=5984.5
# >expected=5855.2, predicted=5909.2
# >expected=5852.5, predicted=5849.3
# >expected=5849.2, predicted=5855.6
# >expected=5842.2, predicted=5853.7
# >expected=5865.8, predicted=5868.3
# >expected=5754.4, predicted=5879.7
# >expected=5671.5, predicted=5660.5
# >expected=5633.3, predicted=5644.7
# >expected=5705.5, predicted=5628.6
# >expected=5758.5, predicted=5674.6
# >expected=5805.9, predicted=5702.6
# >expected=5766.3, predicted=5854.2
# >expected=5759.9, predicted=5693.7
# >expected=5786.1, predicted=5745.4
# >expected=5800.5, predicted=5712.8
# >expected=5879.3, predicted=5843.6
# >expected=5968.4, predicted=5878.9
# >expected=5949.3, predicted=5946.5
# >expected=5846.8, predicted=5970.6
# >expected=5831.8, predicted=5839.0
# >expected=5864.1, predicted=5839.3
# >expected=5844.1, predicted=5791.9
# >expected=5831.7, predicted=5869.4
# >expected=5780.5, predicted=5828.7
# >expected=5759.4, predicted=5715.9
# >expected=5776.7, predicted=5711.2
# >expected=5858.5, predicted=5732.3
# >expected=5829.7, predicted=5897.9
# >expected=5797.6, predicted=5825.5
# >expected=5781.7, predicted=5893.5
# >expected=5752.5, predicted=5752.7
# >expected=5742.0, predicted=5761.0
# >expected=5734.4, predicted=5741.7
# >expected=5640.8, predicted=5704.3
# >expected=5706.0, predicted=5596.3
# >expected=5649.9, predicted=5677.8
# >expected=5605.9, predicted=5660.1
# >expected=5607.7, predicted=5627.9
# >expected=5674.0, predicted=5645.9
# >expected=5677.9, predicted=5698.1
# >expected=5750.1, predicted=5673.8
# >expected=5744.5, predicted=5734.0
# >expected=5776.1, predicted=5720.2
# >expected=5801.3, predicted=5761.2
# >expected=5791.9, predicted=5833.7
# >expected=5840.9, predicted=5825.3
# >expected=5837.7, predicted=5828.1
# >expected=5802.8, predicted=5842.9
# >expected=5785.1, predicted=5809.7
# >expected=5751.8, predicted=5790.4
# >expected=5602.7, predicted=5749.8
# >expected=5611.0, predicted=5599.4
# >expected=5658.1, predicted=5588.7
# >expected=5610.8, predicted=5682.7
# >expected=5599.2, predicted=5613.5
# >expected=5651.7, predicted=5626.0
# >expected=5695.5, predicted=5626.0
# >expected=5663.3, predicted=5740.9
# >expected=5642.9, predicted=5637.9
# >expected=5648.0, predicted=5596.4
# >expected=5622.0, predicted=5644.2
# >expected=5688.9, predicted=5622.4
# >expected=5712.5, predicted=5677.3
# >expected=5697.7, predicted=5755.6
# >expected=5713.2, predicted=5686.2
# >expected=5745.3, predicted=5738.4
# >expected=5776.0, predicted=5762.0
# >expected=5773.0, predicted=5795.9
# >expected=5779.9, predicted=5732.2
# >expected=5745.3, predicted=5802.0
# >expected=5703.7, predicted=5702.6
# >expected=5615.0, predicted=5656.4
# >expected=5669.9, predicted=5618.7
# >expected=5683.6, predicted=5665.0
# >expected=5655.4, predicted=5655.6
# >expected=5658.7, predicted=5640.4
# >expected=5561.2, predicted=5668.9
# >expected=5546.7, predicted=5564.4
# >expected=5615.5, predicted=5526.3
# >expected=5614.3, predicted=5685.1
# >expected=5573.8, predicted=5653.2
# >expected=5509.2, predicted=5590.8
# >expected=5362.9, predicted=5499.7
# >expected=5353.0, predicted=5309.5
# >expected=5330.7, predicted=5380.4
# >expected=5340.3, predicted=5321.4
# >expected=5414.6, predicted=5342.9
# >expected=5533.1, predicted=5402.5
# >expected=5607.9, predicted=5524.6
# >expected=5670.1, predicted=5624.8
# >expected=5673.7, predicted=5662.7
# >expected=5725.7, predicted=5703.9
# >expected=5892.7, predicted=5692.8
# >expected=6032.7, predicted=5857.4
# >expected=6118.9, predicted=5990.2
# >expected=6086.8, predicted=6139.5
# >expected=6097.2, predicted=6087.1
# >expected=6128.3, predicted=6116.4
# >expected=6181.4, predicted=6128.5
# >expected=6141.1, predicted=6214.2
# >expected=6126.1, predicted=6143.5
# >expected=6121.3, predicted=6114.8
# >expected=6132.7, predicted=6106.2
# >expected=6139.6, predicted=6146.2
# >expected=6138.8, predicted=6141.5
# >expected=6203.5, predicted=6139.2
# >expected=6182.0, predicted=6212.6
# >expected=6141.7, predicted=6197.3
# >expected=6148.7, predicted=6094.5
# >expected=6164.2, predicted=6166.2
# >expected=6097.2, predicted=6171.3
# >expected=6150.4, predicted=6125.3
# >expected=6207.0, predicted=6144.7
# >expected=6259.1, predicted=6216.6
# >expected=6323.3, predicted=6235.9
# >expected=6333.8, predicted=6292.5
# >expected=6333.2, predicted=6306.0
# >expected=6337.2, predicted=6332.7
# >expected=6360.0, predicted=6338.7
# >expected=6378.8, predicted=6368.1
# >expected=6344.2, predicted=6357.0
# >expected=6350.3, predicted=6332.3
# >expected=6318.5, predicted=6391.0
# >expected=6312.2, predicted=6331.4
# >expected=6354.1, predicted=6318.2
# >expected=6355.0, predicted=6412.4
# >expected=6335.1, predicted=6373.4
# >expected=6258.6, predicted=6333.5
# >expected=6208.3, predicted=6150.7
# >expected=6223.8, predicted=6142.2
# >expected=6270.8, predicted=6251.1
# >expected=6298.6, predicted=6266.4
# >expected=6299.0, predicted=6309.9
# >expected=6309.4, predicted=6307.9
# >expected=6396.0, predicted=6341.2
# >expected=6345.4, predicted=6417.6
# >expected=6254.2, predicted=6311.7
# >expected=6266.8, predicted=6231.9
# >expected=6366.0, predicted=6222.2
# >expected=6388.5, predicted=6416.8
# >expected=6592.5, predicted=6403.6
# >expected=6647.1, predicted=6599.5
# >expected=6662.6, predicted=6624.7
# >expected=6677.0, predicted=6664.7
# >expected=6607.7, predicted=6685.2
# >expected=6557.5, predicted=6584.0
# >expected=6544.4, predicted=6526.1
# >expected=6580.4, predicted=6535.3
# >expected=6538.5, predicted=6601.2
# >expected=6516.9, predicted=6527.8
# >expected=6522.6, predicted=6487.8
# >expected=6524.1, predicted=6521.1
# >expected=6532.8, predicted=6512.5
# >expected=6527.3, predicted=6532.4
# >expected=6482.6, predicted=6542.5
# >expected=6494.9, predicted=6402.7
# >expected=6455.8, predicted=6496.1
# >expected=6449.5, predicted=6422.1
# >expected=6358.0, predicted=6449.6
# >expected=6298.8, predicted=6331.4
# >expected=6212.8, predicted=6298.1
# >expected=6187.1, predicted=6272.3
# >expected=6264.0, predicted=6224.1
# >expected=6307.9, predicted=6284.5
# >expected=6312.6, predicted=6328.8
# >expected=6291.3, predicted=6353.5
# >expected=6288.0, predicted=6262.0
# >expected=6311.5, predicted=6270.8
# >expected=6320.0, predicted=6334.6
# >expected=6327.2, predicted=6322.2
# >expected=6318.7, predicted=6329.2
# >expected=6312.2, predicted=6312.9
# >expected=6339.8, predicted=6303.1
# >expected=6408.9, predicted=6324.9
# >expected=6521.7, predicted=6405.1
# >expected=6542.8, predicted=6512.0
# >expected=6516.9, predicted=6505.8
# >expected=6438.8, predicted=6509.5
# >expected=6414.6, predicted=6420.2
# >expected=6397.2, predicted=6429.1
# >expected=6399.2, predicted=6421.7
# >expected=6409.0, predicted=6407.7
# >expected=6443.2, predicted=6449.3
# >expected=6443.6, predicted=6475.5
# >expected=6346.6, predicted=6448.9
# >expected=6327.0, predicted=6274.7
# >expected=6387.0, predicted=6303.1
# >expected=6430.8, predicted=6409.2
# >expected=6461.3, predicted=6461.2
# >expected=6434.4, predicted=6463.3
# >expected=6481.9, predicted=6456.8
# >expected=6518.8, predicted=6438.9
# >expected=6506.4, predicted=6532.0
# >expected=6550.5, predicted=6489.4
# >expected=6548.2, predicted=6552.2
# >expected=6559.6, predicted=6568.3
# >expected=6577.4, predicted=6545.3
# >expected=6629.8, predicted=6578.3
# >expected=6605.0, predicted=6625.5
# >expected=6624.6, predicted=6598.4
# >expected=6614.5, predicted=6638.2
# >expected=6592.8, predicted=6640.3
# >expected=6559.4, predicted=6611.6
# >expected=6551.2, predicted=6546.9
# >expected=6548.5, predicted=6546.8
# >expected=6524.5, predicted=6535.3
# >expected=6526.1, predicted=6507.3
# >expected=6532.3, predicted=6527.9
# >expected=6575.9, predicted=6522.3
# >expected=6591.4, predicted=6598.5
# >expected=6589.3, predicted=6610.8
# >expected=6612.1, predicted=6593.6
# >expected=6582.8, predicted=6620.8
# >expected=6600.8, predicted=6580.3
# >expected=6621.5, predicted=6584.7
# >expected=6621.5, predicted=6633.5
# >expected=6623.5, predicted=6632.7
# >expected=6666.1, predicted=6612.0
# >expected=6731.2, predicted=6668.5
# >expected=6776.9, predicted=6769.6
# >expected=6779.1, predicted=6793.0
# >expected=6764.3, predicted=6787.4
# >expected=6741.8, predicted=6756.6
# >expected=6735.9, predicted=6781.9
# >expected=6769.5, predicted=6796.3
# >expected=6835.4, predicted=6786.5
# >expected=6868.2, predicted=6829.4
# >expected=6875.2, predicted=6868.9
# >expected=6858.1, predicted=6880.4
# >expected=6758.6, predicted=6855.1
# >expected=6758.8, predicted=6748.5
# >expected=6769.2, predicted=6777.0
# >expected=6775.9, predicted=6792.7
# >expected=6784.9, predicted=6785.6
# >expected=6809.7, predicted=6755.5
# >expected=6808.9, predicted=6817.5
# >expected=6825.2, predicted=6785.3
# >expected=6836.2, predicted=6839.7
# >expected=6828.3, predicted=6819.9
# >expected=6829.5, predicted=6845.0
# >expected=6831.1, predicted=6808.4
# >expected=6827.8, predicted=6825.1
# >expected=6885.0, predicted=6835.7
# >expected=6938.7, predicted=6917.3
# >expected=6990.4, predicted=6957.1
# >expected=7018.3, predicted=7013.5
# >expected=6970.3, predicted=7081.1
# >expected=6830.2, predicted=6898.6
# >expected=6843.0, predicted=6776.5
# >expected=6815.8, predicted=6850.3
# >expected=6897.5, predicted=6788.1
# >expected=6922.8, predicted=6899.0
# >expected=6914.3, predicted=6959.6
# >expected=6907.7, predicted=6909.3
# >expected=6841.1, predicted=6883.0
# >expected=6883.2, predicted=6839.7
# >expected=6898.4, predicted=6914.5
# >expected=6911.7, predicted=6942.1
# >expected=6928.2, predicted=6910.6
# >expected=6919.3, predicted=6946.7
# >expected=6909.4, predicted=6856.7
# >expected=6913.6, predicted=6892.6
# >expected=6918.2, predicted=6914.6
# >expected=6895.5, predicted=6900.1
# >expected=6893.6, predicted=6903.1
# >expected=6965.3, predicted=6911.9
# >expected=6986.3, predicted=6971.2
# >expected=6954.7, predicted=6998.9
# >expected=6953.8, predicted=6953.0
# >expected=6958.8, predicted=6923.0
# >expected=6971.7, predicted=6921.8
# >expected=6988.2, predicted=6957.1
# >expected=6968.7, predicted=7006.5
# >expected=6984.6, predicted=6949.5
# >expected=7020.6, predicted=6966.5
# >expected=7049.3, predicted=7034.1
# >expected=7048.1, predicted=7052.4
# >expected=7069.4, predicted=7010.5
# >expected=7065.8, predicted=7099.6
# >expected=7044.8, predicted=7040.7
# >expected=6961.9, predicted=7029.8
# >expected=6879.2, predicted=6831.9
# >expected=6940.6, predicted=6893.6
# >expected=6976.8, predicted=6967.1
# >expected=6984.6, predicted=7025.8
# >expected=7007.4, predicted=6996.2
# >expected=7028.1, predicted=7005.1
# >expected=7041.7, predicted=7007.5
# >expected=6991.4, predicted=7039.4
# >expected=6984.0, predicted=6967.2
# >expected=6954.6, predicted=6977.6
# >expected=7015.2, predicted=6945.7
# >expected=7032.4, predicted=7037.6
# >expected=7028.6, predicted=7036.3
# >expected=7047.9, predicted=7042.8
# >expected=7021.1, predicted=7043.9
# >expected=7033.0, predicted=7028.0
# >expected=6941.5, predicted=7031.2
# >expected=6983.6, predicted=6869.3
# >expected=7002.7, predicted=6917.2
# >expected=7008.8, predicted=6981.1
# >expected=7023.9, predicted=7013.1
# >expected=6988.4, predicted=7039.8
# >expected=6933.0, predicted=6948.0
# >expected=6911.7, predicted=6942.5
# >expected=6856.6, predicted=6914.9
# >expected=6760.1, predicted=6880.1
# >expected=6785.3, predicted=6759.9
# >expected=6882.7, predicted=6807.1
# >expected=6885.2, predicted=6937.4
# >expected=6915.3, predicted=6887.3
# >expected=6910.8, predicted=6862.8
# >expected=6914.8, predicted=6897.6
# >expected=6892.7, predicted=6892.8
# >expected=6904.4, predicted=6885.7
# >expected=6954.4, predicted=6912.2
# >expected=6923.2, predicted=6955.0
# >expected=6947.8, predicted=6915.1
# >expected=6970.1, predicted=6943.3
# >expected=7003.8, predicted=6951.8
# >expected=7019.6, predicted=6962.9
# >expected=7022.0, predicted=7058.9
# >expected=7026.6, predicted=7022.2
# >expected=7018.1, predicted=7011.3
# >expected=7026.3, predicted=7015.6
# >expected=7058.2, predicted=7018.1
# >expected=7115.5, predicted=7066.7
# >expected=7133.2, predicted=7128.4
# >expected=7144.6, predicted=7065.2
# >expected=7117.9, predicted=7099.6
# >expected=7085.4, predicted=7081.5
# >expected=7096.2, predicted=7069.0
# >expected=7084.1, predicted=7067.8
# >expected=7008.2, predicted=7048.3
# >expected=7021.6, predicted=7032.0
# >expected=7064.5, predicted=7046.5
# >expected=7063.7, predicted=7102.5
# >expected=7056.0, predicted=7101.2
# >expected=7081.7, predicted=7040.9
# >expected=7077.4, predicted=7071.2
# >expected=7088.3, predicted=7048.1
# >expected=7101.0, predicted=7060.0
# >expected=7099.9, predicted=7051.5
# >expected=7080.6, predicted=7041.5
# >expected=7110.9, predicted=7055.8
# >expected=7115.2, predicted=7100.6
# >expected=7122.1, predicted=7077.9
# >expected=7104.2, predicted=7126.8
# >expected=7142.2, predicted=7090.3
# >expected=7113.3, predicted=7143.3
# >expected=7056.8, predicted=7112.8
# >expected=6985.7, predicted=7071.0
# >expected=7002.9, predicted=6988.9
# >expected=6986.5, predicted=6950.9
# >expected=7032.8, predicted=6977.9
# >expected=7006.7, predicted=7018.7
# >expected=7006.3, predicted=6975.2
# >expected=7018.3, predicted=6967.1
# >expected=6980.3, predicted=7020.2
# >expected=6917.3, predicted=6936.2
# >expected=6854.9, predicted=6907.3
# >expected=6938.0, predicted=6845.3
# >expected=7036.7, predicted=6943.3
# >expected=7061.3, predicted=7078.1
# >expected=7030.6, predicted=7066.9
# >expected=7053.1, predicted=7019.5
# >expected=7039.1, predicted=7040.4
# >expected=7003.7, predicted=7011.5
# >expected=7057.7, predicted=6974.6
# >expected=7064.3, predicted=7055.0
# >expected=7006.9, predicted=7107.6
# MAE: 42.636
# 2023-06-17 00:49:27 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:49:27 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:49:27 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:49:27 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-17 00:49:27 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 1170
# 1170

# %% [markdown]
# ### 3. Reading predictions and backtesting the XGBoost trading strategy

# %% [markdown]
# #### 3.1 XGBoost trading strategy on Fuel futures contracts

# %% [markdown]
# ### 3. XGBoost Backtesting
# - The following implementations simply grab the pre-computed predictions from the relevant file and carries out the backtesting

# %% [markdown]
# #### 3.1 XGBoost Backtesting on Fuel Contracts

# %%
# figure, axs = plt.subplots(2, 1, figsize=(20, 10))    
fuel_accounts = []
time_steps = 6
for i in range(len(fuel_futures)):    
    fuel_preds = pd.read_csv(f'../ARIMA-XGBoost-saved-data/{fuel_futures[i]}_daily_predictions.csv', parse_dates=True)
    fuel_preds['Datetime'] = pd.to_datetime(fuel_preds['Datetime'])
    fuel_preds = fuel_preds.set_index(['Datetime'])
    
    test_startdate = pd.Timestamp('2018-01-01')
    
    forecasts = fuel_preds.diff()

    # Convert csv data into data object for pysystemtrade
    instrument_data = csvFuturesSimData(csv_data_paths=dict(csvFuturesAdjustedPricesData="data.firstrate_futures.xgboost"))

    # Get the daily prices for backtesting
    price = pd.read_csv(f'../pysystemtrade/data/firstrate_futures/xgboost/{fuel_futures[i]}_daily.csv', parse_dates=True)
    price['DATETIME'] = pd.to_datetime(price['DATETIME'])
    price = price.set_index(['DATETIME'])
    price = price[test_startdate:]
    price = price[time_steps:]
    price_series = pd.Series(price['price'])
    account = pandl_for_instrument_forecast(forecast=forecasts['0'], price=price_series)
    fuel_accounts.append(account)
# Out:
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:03 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)

# %%
plt.rcParams.update({
    "font.size": 16,
    "legend.fontsize": 14
})

figure, axs = plt.subplots(2, 1, figsize=(20, 10))
figure.subplots_adjust(hspace=0.5)
for i in range(len(fuel_accounts)):
    axs[0].plot(fuel_accounts[i].curve(), label=f'{fuel_futures[i]}')
    axs[0].title.set_text('Profit and Loss (XGBoost)')
    axs[0].legend()
    axs[0].set_ylabel('PnL')
    axs[0].set_xlabel('Time')

    axs[1].plot(fuel_accounts[i].drawdown(), label=f'{fuel_futures[i]}')
    axs[1].legend()
    axs[1].title.set_text('Drawdown (XGBoost)')
    axs[1].set_ylabel('Drawdown')
    axs[1].set_xlabel('Time')

# %%
# Gather all statistics
fuel_account_statistics = pd.DataFrame(columns=fuel_futures)

for i in range(len(fuel_accounts)):
    
    fuel_account_statistics['STATISTICS'] = pd.Series(list(dict(fuel_accounts[i].percent.stats()[0]).keys()))

    fuel_account_statistics[fuel_futures[i]] = pd.Series([float(x) for x in list(dict(fuel_accounts[i].percent.stats()[0]).values())])
    
    print(round(fuel_accounts[i].curve().iloc[-1], 6))
            
fuel_account_statistics_rounded = fuel_account_statistics.round(decimals=6)
fuel_account_statistics_rounded
# Out:
# -6.290279
# 0.381605
# -0.915932
# 0.013394
# -0.142363
#           CL         NG        BZ        RB        HO              STATISTICS
# 0  -0.964800  -0.065900 -1.556000 -0.023930 -0.039510                     min
# 1   1.161000   0.260500  1.248000  0.026110  0.014690                     max
# 2  -0.000155   0.000000 -0.000215 -0.000002 -0.000021                  median
# 3  -0.006452   0.000391 -0.000939  0.000014 -0.000146                    mean
# 4   0.118600   0.012100  0.135200  0.003358  0.003418                     std
# 5  -0.195300  11.040000 -0.359100  0.193300 -2.129000                    skew
# 6  -1.652000   0.100200 -0.240500  0.003517 -0.037380                ann_mean
# 7   1.898000   0.193600  2.164000  0.053730  0.054690                 ann_std
# 8  -0.870100   0.517500 -0.111100  0.065460 -0.683500                  sharpe
# 9  -0.978100   0.947100 -0.128300  0.083380 -0.725000                 sortino
# 10 -3.271000  -0.086590 -2.279000 -0.023410 -0.087880            avg_drawdown
# 11  0.978500   0.970300  0.960000  0.926200  0.985600        time_in_drawdown
# 12 -0.246300   0.440000 -0.045260  0.027970 -0.233300                  calmar
# 13 -0.504900   1.157000 -0.105500  0.150200 -0.425400  avg_return_to_drawdown
# 14 -0.070110  -0.004052 -0.068030 -0.001934 -0.001970                avg_loss
# 15  0.059880   0.004929  0.068400  0.002024  0.001819                avg_gain
# 16  0.854100   1.216000  1.005000  1.046000  0.923800         gaintolossratio
# 17  0.817600   1.194000  0.972500  1.014000  0.855400            profitfactor
# 18  0.489100   0.495300  0.491700  0.492200  0.480800                 hitrate
# 19 -1.698000   1.010000 -0.216900  0.127700 -1.334000                  t_stat
# 20  0.089820   0.312800  0.828300  0.898400  0.182500                 p_value

# %% [markdown]
# #### 3.2 XGBoost Backtesting on Equity Contracts

# %%
equity_accounts = []
time_steps = 6
for i in range(len(equity_futures)):    
    equity_preds = pd.read_csv(f'../ARIMA-XGBoost-saved-data/{equity_futures[i]}_daily_predictions.csv', parse_dates=True)
    equity_preds['Datetime'] = pd.to_datetime(equity_preds['Datetime'])
    equity_preds = equity_preds.set_index(['Datetime'])
    
    test_startdate = pd.Timestamp('2018-01-01')
    
    forecasts = equity_preds.diff()

    # Convert csv data into data object for pysystemtrade
    instrument_data = csvFuturesSimData(csv_data_paths=dict(csvFuturesAdjustedPricesData="data.firstrate_futures.xgboost"))

    # Get the daily prices for backtesting
    price = pd.read_csv(f'../pysystemtrade/data/firstrate_futures/xgboost/{equity_futures[i]}_daily.csv', parse_dates=True)
    price['DATETIME'] = pd.to_datetime(price['DATETIME'])
    price = price.set_index(['DATETIME'])
    price = price[test_startdate:]
    price = price[time_steps:]
    price_series = pd.Series(price['price'])
    account = pandl_for_instrument_forecast(forecast=forecasts['0'], price=price_series)
    equity_accounts.append(account)
# Out:
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesMultiplePricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFuturesInstrumentData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvFxPricesData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvRollParametersData in csv_data_paths, will use defaults (may break in production, should be fine in sim)
# 2023-06-23 12:23:22 {'type': 'csvFuturesSimData'} [Warning] No key for csvSpreadCostData in csv_data_paths, will use defaults (may break in production, should be fine in sim)

# %%
plt.rcParams.update({
    "font.size": 16,
    "legend.fontsize": 14
})

figure, axs = plt.subplots(2, 1, figsize=(20, 10))
figure.subplots_adjust(hspace=0.5)
for i in range(len(equity_accounts)):
    axs[0].plot(equity_accounts[i].curve(), label=f'{equity_futures[i]}')
    axs[0].title.set_text('Profit and Loss (XGBoost)')
    axs[0].legend()
    axs[0].set_ylabel('PnL')
    axs[0].set_xlabel('Time')

    axs[1].plot(equity_accounts[i].drawdown(), label=f'{equity_futures[i]}')
    axs[1].legend()
    axs[1].title.set_text('Drawdown (XGBoost)')
    axs[1].set_ylabel('Drawdown')
    axs[1].set_xlabel('Time')

# %%
equity_account_statistics = pd.DataFrame(columns=equity_futures)

for i in range(len(equity_accounts)):
    
    equity_account_statistics['STATISTICS'] = pd.Series(list(dict(equity_accounts[i].percent.stats()[0]).keys()))

    equity_account_statistics[equity_futures[i]] = pd.Series([float(x) for x in list(dict(equity_accounts[i].percent.stats()[0]).values())])
    
    print(round(equity_accounts[i].curve().iloc[-1], 6))
            
equity_account_statistics_rounded = equity_account_statistics.round(decimals=6)
equity_account_statistics_rounded
# Out:
# 125.620017
# -174.971323
# 414.233571
# 932.588213
# 295.564628
#           ES         NQ          FX         DY         X
# 0  -25.42000  -86.03000  -22.740000  -64.15000  -51.7200  \
# 1   31.44000   78.68000   82.770000  279.70000  207.6000
# 2    0.03296    0.00000    0.000000    0.00000    0.0000
# 3    0.12880   -0.17950    0.424900    0.95650    0.3031
# 4    3.20200   12.60000    5.024000   17.43000   10.3500
# 5    0.83170   -0.14210    7.823000    6.12800   11.0900
# 6   32.98000  -45.94000  108.800000  244.90000   77.6000
# 7   51.23000  201.50000   80.380000  278.90000  165.6000
# 8    0.64380   -0.22800    1.353000    0.87810    0.4687
# 9    0.79050   -0.26040    2.776000    1.56800    0.8952
# 10 -18.15000 -160.50000  -16.270000  -78.11000  -93.7000
# 11   0.92620    0.96510    0.873800    0.91790    0.9241
# 12   0.54020   -0.08689    1.237000    0.67670    0.2477
# 13   1.81700   -0.28620    6.684000    3.13500    0.8283
# 14  -1.66600   -6.69600   -1.646000   -7.01200   -3.4820
# 15   1.66100    6.48300    2.468000    9.07900    4.1830
# 16   0.99700    0.96820    1.499000    1.29500    1.2010
# 17   1.17000    0.94630    1.531000    1.27600    1.1740
# 18   0.54000    0.49430    0.505200    0.49630    0.4943
# 19   1.25700   -0.44490    2.641000    1.71400    0.9147
# 20   0.20920    0.65650    0.008407    0.08693    0.3606
#
#                 STATISTICS
# 0                      min
# 1                      max
# 2                   median
# 3                     mean
# 4                      std
# 5                     skew
# 6                 ann_mean
# 7                  ann_std
# 8                   sharpe
# 9                  sortino
# 10            avg_drawdown
# 11        time_in_drawdown
# 12                  calmar
# 13  avg_return_to_drawdown
# 14                avg_loss
# 15                avg_gain
# 16         gaintolossratio
# 17            profitfactor
# 18                 hitrate
# 19                  t_stat
# 20                 p_value
